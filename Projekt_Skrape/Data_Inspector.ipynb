# %%
import os
import pandas as pd

# %%
os.getcwd()
# Out:
# '/Volumes/GoogleDrive/My Drive/508/Projekt_Skrape'

# %%
os.listdir()
# Out:
# ['geckodriver.log',
#  'chromedriver',
#  'Splinter_Weather_scrape_build.ipynb',
#  '.DS_Store',
#  '.ipynb_checkpoints',
#  'year',
#  'Untitled.ipynb',
#  'Data_Inspector.ipynb',
#  'linbergh_field',
#  'Campo',
#  '.virtual_documents']

# %%
# Not case sensitive!
loc = 'san diego brown field'
month = 'may'
year = '2018'

# %%
os.listdir(f'{loc}/{loc}_{year}/')
# Out:
# ['2018_January.csv',
#  '2018_February.csv',
#  '2018_March.csv',
#  '2018_April.csv',
#  '2018_May.csv',
#  '2018_June.csv',
#  '2018_July.csv',
#  '2018_August.csv',
#  '2018_September.csv',
#  '2018_October.csv',
#  '2018_November.csv',
#  '2018_December.csv']

# %%
df = pd.read_csv(f'{loc}/{loc}_{year}/{year}_{month}.csv')
df
# Out:
#     Unnamed: 0             0               1                2             3  \
# 0            0  KSDM 05/2018    KSDM 05/2018     KSDM 05/2018  KSDM 05/2018
# 1            1          Date  ObservedLow(F)  ObservedHigh(F)  NormalLow(F)
# 2            2             1              51               59            52
# 3            3             2              51               63            52
# 4            4             3              49               70            53
# 5            5             4              49               86            53
# 6            6             5              55               82            53
# 7            7             6              54               77            53
# 8            8             7              52               73            53
# 9            9             8              52               72            53
# 10          10             9              56               73            53
# ...
